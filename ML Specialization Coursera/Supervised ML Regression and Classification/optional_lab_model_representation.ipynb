# %% [markdown]
# # Optional Lab: Model Representation

# %% [markdown]
# ## Goals
# In this lab you will:
# - Learn to implement the model $f_{w,b}$ for linear regression with one variable

# %% [markdown]
# ## Notaion
#
# Here is a summary of some notations.

# %% [markdown]
# ## Tools
# - NumPy : A popular library for scientific computing
# - Matplotlib : For plotting data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem Statement
# <img align="left" src="./image/C1_W1_L3_S1_trainingdata.png" style="width:380px; padding: 10px;" />
# A house with 100 square feet (sqft) sold for $300,00 and a house with 2000 square feet sold for $500,000. These two points will constitute our data or training set. The units of size are 1000 sqft and the units of price are 1000s of dollars.
#
# | Size (1000 sqft)      | Price (1000s of dollars) |
# | ----------------------| -------------------------|
# | 1.0                   | 300                      |
# | 2.0                   | 500                      |
#
# We have to fit a linear regression model (shown above as the blue straight line) through these two points, so we can then predict price for other houses.

# %% [markdown]
# Now create `x_train` and `y_train` variables. The data is stored in 1D NumPy arrays.

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# ### Number of training examples `m`
#
# NumPy arrays have a `.shape` parameter. `x_train.shape` returns a python tuple with an entry for each dimension. `x_train.shape[0]` is the length of the array and number of examples.
# We can also use `len()`.

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %%
m = len(x_train)
print(f"Number of training examples is: {m}")
# Out:
# Number of training examples is: 2

# %% [markdown]
# ### Training example `x_i` `y_i`
#
# We will use $(x^{(i)}, y^{(i)})$ to denote the $i^{th}$ training example.

# %%
i = 0
x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %% [markdown]
# ### Plotting the data
#
# We can plot these two points using the `scatter()` function.

# %%
# Plot the data points
plt.figure(figsize=(4, 3))
plt.scatter(x_train, y_train, marker='x', c='r')
plt.title("Housing Prices")
plt.ylabel('Prices (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')

plt.show()

# %% [markdown]
# ## Model function
#
# <img align="left" src="./image/C1_W1_L3_S1_model.png"     style=" width:380px; padding: 10px; " >
#
# The Model function for linear regression is represented as
#
# $$ f_{w, b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#
# Let's start with $w = 100$ and $b = 100$

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# Now, let's compute the value of $f_{w, b}(x^{(i)})$ for our two data points.
#
# for $x^{(0)}$, `$f_wb = w * x[0] + b`
#
# for $x^{(1)}$, `$f_wb = w * x[1] + b`

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
        x (ndarray (m,)): Data, m examples
        w, b (scalar)   : model parameters
    Returns
        f_wb (ndarray (m,)): model preduction 
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
    return f_wb

# %% [markdown]
# Now let's call the compute_model_output function and plot the output.

# %%
def compute_and_plot():
    tmp_f_wb = compute_model_output(x_train, w, b)

    # Plot our data model prediction
    plt.figure(figsize=(4, 3))
    plt.plot(x_train, tmp_f_wb, c='b', label='Our Prediction')

    # Plot the data points
    plt.scatter(x_train, y_train, marker='x', c='r', label='Actual Values')

    plt.title("Housing Prices")
    plt.ylabel('Price (in 1000s of dollars)')
    plt.xlabel('Size (1000 sqft)')
    plt.legend()
    plt.show()

compute_and_plot()

# %% [markdown]
# For `w = 200` and `b = 100` we got the desired line!

# %%
w = 200
b = 100
compute_and_plot()

# %% [markdown]
# ### Prediction
#
# Now that we have a model, we can use it to make our original prediction.
# Let's predict the price of a house with 1200 sqft. Since the units of x are in 1000's of sqft, x is 1.2

# %%
w = 200
b = 100
x_i = 1.2
cost_1200sqft = w * x_i + b

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars

# %% [markdown]
# In this lab we have learned:
#
# - Linear regression builds a model which establishes a relationship between features and targets
# - In the example above, the feature was house size and the target was house price
# - for simple linear regression, the model has two parameters 𝑤 and 𝑏 whose values are 'fit' using training data.
# - once a model's parameters have been determined, the model can be used to make predictions on novel data.
